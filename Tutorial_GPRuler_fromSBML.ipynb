# %% [markdown]
# # Tutorial: GPRuler using HMRcore model
# This tutorial explains how to use GPRuler with an SBML model as input.

# %%
import pandas as pd

# %% [markdown]
# **Step 1. metaboliteIdentification**
# To run the script from the Jupyter notebook:
# ```
# !python pipeline/metaboliteIdentification.py hmr
# ```
#
# In alternative, to run the script from the terminal:
# ```
# python pipeline/metaboliteIdentification.py hmr
# ```
#
# The two produced outputs are:

# %%
dfOutput1 = pd.read_csv('./tutorial/outputs/hmrCore_metabolites.csv', sep = '\t')
dfOutput1.head()
# Out:
#               Id           Name  KeggId  ChebiId  PubchemId  \
# 0    M_biomass_s       biomasss     NaN      NaN        NaN
# 1    M_glucose_s      D-Glucose     NaN      NaN        NaN
# 2   M_lactateL_s  L-Lactic acid     NaN      NaN        NaN
# 3         M_O2_s         Oxygen     NaN      NaN        NaN
# 4  M_glutamine_s    L-Glutamine     NaN      NaN        NaN
#
#    boundaryCondition  chemicalFormula  Inchi
# 0              False              NaN    NaN
# 1              False              NaN    NaN
# 2              False              NaN    NaN
# 3              False              NaN    NaN
# 4              False              NaN    NaN

# %%
dfOutput2 = pd.read_csv('./tutorial/outputs/hmrCore_metabolites_wInferredIds.csv', sep = '\t')
dfOutput2.head()
# Out:
#                                            Name  \
# 0                              2-Oxoglutaramate
# 1                                           GTP
# 2  (R)-3-Hydroxyoctanoyl-[acyl-carrier protein]
# 3           Flavin Adenine Dinucleotide Reduced
# 4                                    Folic acid
#
#                                          Identifiers
# 0                       ['C00940', '30882', '16769']
# 1                       ['15996', 'C00044', '37565']
# 2                                         ['C04620']
# 3                                                 []
# 4  ['67011', 'CPD-12826', '62501', 'C00504', '374...

# %% [markdown]
# **Step 2. metabolitesIdentification_FuzzyWuzzy**
# To run the script from the Jupyter notebook:
# ```
# !python pipeline/metabolitesIdentification_FuzzyWuzzy.py hmr
# ```
#
# In alternative, to run the script from the terminal:
# ```
# python pipeline/metabolitesIdentification_FuzzyWuzzy.py hmr
# ```
# The produced outputs are:

# %%
dfOutput1 = pd.read_csv('./tutorial/outputs/hmrCore_mappingMetaCyc_allResults.tsv', sep = '\t')
dfOutput1.head()
# Out:
#                                           Unnamed: 0  \
# 0                 2'-Deoxyguanosine 5'-monophosphate
# 1                                                CDP
# 2                                     Isocitric acid
# 3  4alpha-Carboxy-4beta-methyl-5alpha-cholesta-8,...
# 4                                              NADPH
#
#                                                    0  \
# 0         ("2'-deoxyguanosine 3'-monophosphate", 97)
# 1                                       ('CDP', 100)
# 2    ('(+)-dehydrodiconiferyl acid carboxylate', 86)
# 3  ('4&alpha;-carboxy-4&beta;-methyl-5&alpha;-cho...
# 4                                     ('NADPH', 100)
#
#                                                    1  \
# 0         ("2'-deoxyadenosine 3'-monophosphate", 91)
# 1                             ('CDP-2-glycerol', 90)
# 2                    ('juvenile hormone I acid', 86)
# 3  ('4&alpha;-carboxy-4&beta;-methyl-5&alpha;-cho...
# 4                                        ('ADP', 90)
#
#                                                    2  \
# 0         ("3'-deoxyadenosine 5'-monophosphate", 91)
# 1                                ('CDP-ribitol', 90)
# 2                  ('juvenile hormone III acid', 86)
# 3  ('4&alpha;-formyl-4&beta;-methyl-5&alpha;-chol...
# 4                                 ('(S)-NADPHX', 90)
#
#                                                    3  \
# 0                          ("2'-deoxyguanosine", 90)
# 1                   ('CDP-N-methylethanolamine', 90)
# 2                   ('juvenile hormone II acid', 86)
# 3  ('N-[(3R)-6-(5,6-dihydropyridin-2-yl)-7-hydrox...
# 4                                 ('(R)-NADPHX', 90)
#
#                                                    4  \
# 0                                  ('phosphate', 90)
# 1                             ('CDP-D-fructose', 90)
# 2                    ('dihydromonacolin L acid', 86)
# 3  ('N-[(3R)-8-[(2E)-but-2-enoyl]-6-(5,6-dihydrop...
# 4                              ('&alpha;-NADPH', 90)
#
#                                                    5  \
# 0                                  ('guanosine', 90)
# 1                     ('CDP-&alpha;-D-paratose', 90)
# 2  ('3&alpha;-hydroxy-3,5-dihydromonacolin L acid...
# 3           ('8-thiabicyclo[3,2,1]octane-3-one', 86)
# 4                                       ('NADH', 89)
#
#                                                    6  \
# 0  ('2-amino-3-[(2,5-dihydroxyphenyl)sulfanyl]pro...
# 1                             ('CDP-D-mannitol', 90)
# 2  ('O-perylenebutylmethylphosphonic-acid-p-nitro...
# 3       ('(25S)-5-&beta;-spirostan-3-&beta;-ol', 86)
# 4                               ('&alpha;-NADH', 80)
#
#                                                    7  \
# 0  ("3,5-di-C-glucosyl-2,4,4',6-tetrahydroxydiben...
# 1                             ('CDP-D-xylulose', 90)
# 2                  ('8-demethylnovobiocic acid', 86)
# 3                         ('24-epicathasterone', 86)
# 4                    ('1,6-dihydro-&beta;-NADP', 80)
#
#                                                    8  \
# 0  ('2-[2-(1,3-dioxan-2-yl)ethanesulfinyl]-5-phen...
# 1                       ('CDP-&alpha;-abequose', 90)
# 2           ('ulvanobiouronic acid 3-sulfate A', 86)
# 3      ('(Rib-ol)-P-Glc-AATGal-PP-undecaprenol', 86)
# 4                    ('1,2-dihydro-&beta;-NADP', 80)
#
#                                                    9
# 0  ('2-((2-(1,3-dioxan-2-yl)ethyl)thio)-5-phenyl-...
# 1                       ('CDP-&alpha;-tyvelose', 90)
# 2           ('ulvanobiouronic acid 3-sulfate B', 86)
# 3                 ('2-hydroxy-2-methyl-butanal', 86)
# 4                              ('3-acetyl-NADH', 80)

# %%
dfOutput2 = pd.read_csv('./tutorial/outputs/hmrCore_mappingKeggC_allResults.tsv', sep = '\t')
dfOutput2.head()
# Out:
#                                           Unnamed: 0  \
# 0                 2'-Deoxyguanosine 5'-monophosphate
# 1                                                CDP
# 2                                     Isocitric acid
# 3  4alpha-Carboxy-4beta-methyl-5alpha-cholesta-8,...
# 4                                              NADPH
#
#                                                    0  \
# 0        ("2'-Deoxyguanosine 5'-monophosphate", 100)
# 1                                       ('CDP', 100)
# 2                            ('Isocitric acid', 100)
# 3  ('4alpha-Carboxy-4beta-methyl-5alpha-cholesta-...
# 4                                     ('NADPH', 100)
#
#                                                    1  \
# 0               ('Deoxyguanosine monophosphate', 95)
# 1                             ('CDP-ascarylose', 90)
# 2                     ('D-threo-Isocitric acid', 90)
# 3  ('4alpha-Carboxy-5alpha-cholesta-8,24-dien-3be...
# 4   ('[Oxidized NADPH---hemoprotein reductase]', 90)
#
#                                             2  \
# 0  ("2'-Deoxyadenosine 5'-monophosphate", 94)
# 1                         ('CDP-glucose', 90)
# 2                                ('Acid', 90)
# 3  ('5alpha-Cholesta-8,24-dien-3beta-ol', 90)
# 4                                   ('P', 90)
#
#                                                    3  \
# 0             ("2'-Deoxyguanosine 5'-phosphate", 94)
# 1                              ('CDP-D-Glucose', 90)
# 2                                         ('RI', 90)
# 3  ('4alpha-Methyl-5alpha-cholesta-7-en-3beta-ol'...
# 4                                ('alpha-NADPH', 90)
#
#                                                  4  \
# 0         ("2'-Deoxyguanosine 5'-diphosphate", 91)
# 1                              ('CDP-choline', 90)
# 2                 ('D-erythro-Isocitric acid', 90)
# 3       ('5alpha-Cholesta-7,24-dien-3beta-ol', 87)
# 4  ('[Reduced NADPH---hemoprotein reductase]', 90)
#
#                                                 5  \
# 0                               ('Phosphate', 90)
# 1                             ('CDPtyvelose', 90)
# 2                             ('Citric acid', 88)
# 3  ('Trimethylcolchicinic acid methyl ether', 86)
# 4                                     ('Na+', 90)
#
#                                                 6  \
# 0       ("2'-Deoxyguanosine 5'-triphosphate", 90)
# 1                                       ('P', 90)
# 2  ('Trimethylcolchicinic acid methyl ether', 86)
# 3                 ('Oleic acid methyl ester', 86)
# 4                                      ('H+', 90)
#
#                                         7                              8  \
# 0                       ('Guanosine', 90)         ('Deoxyguanosine', 90)
# 1                               ('C', 90)    ('CDP-1L-myo-inositol', 90)
# 2  ('2-n-Propyl-4-oxopentanoic acid', 86)  ('Aromatic L-amino acid', 86)
# 3                   ('Methyl oleate', 86)           ('Propane-1-ol', 86)
# 4                             ('ADP', 90)                      ('A', 90)
#
#                                  9
# 0        ("2'-Deoxyguanosine", 90)
# 1         ('CDP-ethanolamine', 90)
# 2  ('Oleic acid methyl ester', 86)
# 3              ('Propan-1-ol', 86)
# 4        ('(R)-NADPH-hydrate', 90)

# %%
dfOutput3 = pd.read_csv('./tutorial/outputs/hmrCore_mappingKeggG_allResults.tsv', sep = '\t')
dfOutput3.head()
# Out:
#                                           Unnamed: 0  \
# 0                 2'-Deoxyguanosine 5'-monophosphate
# 1                                                CDP
# 2                                     Isocitric acid
# 3  4alpha-Carboxy-4beta-methyl-5alpha-cholesta-8,...
# 4                                              NADPH
#
#                                0                              1  \
# 0           ('Sialyldi-Y-2', 86)           ('Glycolipid 2', 86)
# 1                    ('ADP', 67)                    ('GDP', 67)
# 2  ('UDP-D-glucuronic acid', 86)  ('Polygalacturonic acid', 86)
# 3              ("3',8'-LD1", 86)  ('Methyl-glucuronoxylan', 86)
# 4                    ('ADP', 90)                      (nan, 60)
#
#                                      2  \
# 0       ("Adenosine 5'-phosphate", 86)
# 1                          ('CMP', 67)
# 2  ('CMP-N-acetylneuraminic acid', 86)
# 3                 ("3',8'-isoLD1", 86)
# 4                            (nan, 60)
#
#                                                    3  \
# 0  ("3-Deoxy-D-manno-octulosonyl-2',3',2',3'-tetr...
# 1                                        ('UDP', 67)
# 2  ('homopolymer of alpha 2,8-N-acetyl neuraminic...
# 3                                  ('GT1aalpha', 67)
# 4                                          (nan, 60)
#
#                                                    4  \
# 0  ('alpha-Kdo-(2->8)-[alpha-Kdo-(2->4)]-alpha-Kd...
# 1                         ('Dec-P-P-GlcNAc-Rha', 60)
# 2                    ('UDP-D-galacturonic acid', 86)
# 3                                       ('MS 8', 57)
# 4                                          (nan, 60)
#
#                                 5                            6  \
# 0    ('NodRm-IV(Ac,C16:2,S)', 86)  ('delta DiH-2,N,6triS', 86)
# 1  ('Lacto-N-fucopentaose V', 60)         ('UDP-D-xylose', 60)
# 2             ('Pectic acid', 72)       ('Cytidylic acid', 64)
# 3                ('Chitosan', 56)             ('Acarbose', 56)
# 4                       (nan, 60)                    (nan, 60)
#
#                                7                      8  \
# 0  ('delta-DiH-(2,6,N)triS', 86)  ('VIM-2 antigen', 86)
# 1             ('UDP-xylose', 60)        ('Ac2PIM2', 60)
# 2       ('Pharbitic acid C', 64)   ('Alginic acid', 62)
# 3               ('GM1alpha', 56)       ('GM2alpha', 56)
# 4                      (nan, 60)              (nan, 60)
#
#                           9
# 0             ('DWA-2', 86)
# 1  ('Viridopentaose B', 60)
# 2      ('Alginic acid', 62)
# 3          ('Chitosan', 56)
# 4                 (nan, 60)

# %%
dfOutput4 = pd.read_csv('./tutorial/outputs/hmrCore_mappingChebi_allResults.tsv', sep = '\t')
dfOutput4.head()
# Out:
#                                           Unnamed: 0  \
# 0                 2'-Deoxyguanosine 5'-monophosphate
# 1                                                CDP
# 2                                     Isocitric acid
# 3  4alpha-Carboxy-4beta-methyl-5alpha-cholesta-8,...
# 4                                              NADPH
#
#                                                    0  \
# 0        ("2'-Deoxyguanosine 5'-monophosphate", 100)
# 1                                       ('CDP', 100)
# 2                            ('Isocitric acid', 100)
# 3  ('4alpha-Carboxy-4beta-methyl-5alpha-cholesta-...
# 4                                     ('NADPH', 100)
#
#                                                    1  \
# 0        ("2'-deoxyguanosine 5'-monophosphate", 100)
# 1                                       ('CDP', 100)
# 2                            ('ISOCITRIC ACID', 100)
# 3  ('4alpha-carboxyl-4beta-methyl-5alpha-cholesta...
# 4                                     ('NADPH', 100)
#
#                                                    2  \
# 0        ("2'-deoxyguanosine 5'-monophosphate", 100)
# 1                                       ('CDP', 100)
# 2                            ('isocitric acid', 100)
# 3  ('4alpha-Carboxy-4beta-methyl-5alpha-cholesta-...
# 4                                     ('NADPH', 100)
#
#                                                    3  \
# 0         ("2'-deoxyguanosine-3'-monophosphate", 97)
# 1                                       ('CDP', 100)
# 2                            ('isocitric acids', 97)
# 3  ('4-alpha-carboxyl-4-beta-methyl-5-alpha-chole...
# 4                                     ('NADPH', 100)
#
#                                                    4  \
# 0         ("2'-deoxyguanosine 3'-monophosphate", 97)
# 1                                       ('CDP', 100)
# 2                   ('(+)-threo-isocitric acid', 95)
# 3  ('4alpha-methyl-5alpha-cholesta-8,24-dien-3bet...
# 4                                    ('6-NADPH', 95)
#
#                                                    5  \
# 0     ("2'-deoxyguanosine 5'-monophosphate(2-)", 97)
# 1                                 ('CDPribitol', 90)
# 2                     ('D-threo-Isocitric acid', 90)
# 3  ('4alpha-carboxy-4beta-methyl-cholesta-8,24-di...
# 4                                  ('NADPH(4-)', 95)
#
#                                                    6  \
# 0               ('Deoxyguanosine monophosphate', 95)
# 1                   ('CDP-N-methylethanolamine', 90)
# 2                                       ('Acid', 90)
# 3  ('4alpha-methyl-5alpha-cholesta-8,24-dien-3bet...
# 4                                         ('H+', 90)
#
#                                                    7  \
# 0   ("8-oxo-2'-deoxyguanosine-5'-monophosphate", 95)
# 1                            ('CDPacylglycerol', 90)
# 2                                         ('RI', 90)
# 3  ('4alpha-carboxy-4beta-methyl-5alpha-cholest-8...
# 4                                        ('ADP', 90)
#
#                                                    8  \
# 0            ("Deoxyguanosine 5'-monophosphate", 95)
# 1                     ('CDP-1,2-diacylglycerol', 90)
# 2                                       ('[SO]', 90)
# 3  ('4alpha-carboxy-4beta-methyl-5alpha-cholest-8...
# 4                                        ('NAD', 90)
#
#                                                    9
# 0  ("6-O-benzyl-2'-deoxyguanosine 5'-monophosphat...
# 1                          ('CDPdiacylglycerol', 90)
# 2                                         ('SO', 90)
# 3  ('4beta-carboxy-4alpha-methyl-5alpha-cholesta-...
# 4                                       ('NAD+', 90)

# %% [markdown]
# **Step 3. metabolitesIdentification_FuzzyWuzzy_part2**
# To run the script from the Jupyter notebook:
# ```
# !python pipeline/metabolitesIdentification_FuzzyWuzzy_part2.py hmr
# ```
#
# In alternative, to run the script from the terminal:
# ```
# python pipeline/metabolitesIdentification_FuzzyWuzzy_part2.py hmr
# ```
# Some of the produced outputs are the following ones (not all the outputs are shown because structurally equal to the here reported ones):

# %%
dfOutput1 = pd.read_csv('./tutorial/outputs/hmrCore_mappingMetaCyc_100.tsv', sep = '\t')
dfOutput1.head()
# Out:
#    Unnamed: 0                     Name                      Matches
# 0           0                      GMP                      ['GMP']
# 1           1                     dUDP                     ['dUDP']
# 2           2  D-Erythrose 4-phosphate  ['D-erythrose 4-phosphate']
# 3           3                L-Proline                ['L-proline']
# 4           4              Cholesterol              ['cholesterol']

# %%
dfOutput2 = pd.read_csv('./tutorial/outputs/hmrCore_mappingKeggG_100.tsv', sep = '\t')
dfOutput2.head()
# Out:
#    Unnamed: 0                    Name                     Matches
# 0           0  Uridine 5'-diphosphate  ["Uridine 5'-diphosphate"]
# 1           1                     GDP                     ['GDP']

# %%
dfOutput3 = pd.read_csv('./tutorial/outputs/hmrCore_mappingChebi_100.tsv', sep = '\t')
dfOutput3.head()
# Out:
#    Unnamed: 0                                Name  \
# 0           0                      Isocitric acid
# 1           1                                 GMP
# 2           2     5Alpha-Cholesta-8,24-Dien-3-One
# 3           3  2'-Deoxyguanosine 5'-monophosphate
# 4           4                                dUDP
#
#                                   Matches
# 0                      ['Isocitric acid']
# 1                                 ['GMP']
# 2     ['5alpha-cholesta-8,24-dien-3-one']
# 3  ["2'-Deoxyguanosine 5'-monophosphate"]
# 4                                ['dUDP']

# %%
dfOutput4 = pd.read_csv('./tutorial/outputs/hmrCore_mappingKeggC_100.tsv', sep = '\t')
dfOutput4.head()
# Out:
#    Unnamed: 0                                Name  \
# 0           0                      Isocitric acid
# 1           1                                 GMP
# 2           2     5Alpha-Cholesta-8,24-Dien-3-One
# 3           3  2'-Deoxyguanosine 5'-monophosphate
# 4           4                                dUDP
#
#                                   Matches
# 0                      ['Isocitric acid']
# 1                                 ['GMP']
# 2     ['5alpha-Cholesta-8,24-dien-3-one']
# 3  ["2'-Deoxyguanosine 5'-monophosphate"]
# 4                                ['dUDP']

# %% [markdown]
# **Step 4. metabolitesIdentification_joiningData**
# To run the script from the Jupyter notebook:
# ```
# !python pipeline/metabolitesIdentification_joiningData.py hmr
# ```
#
# In alternative, to run the script from the terminal:
# ```
# python pipeline/metabolitesIdentification_joiningData.py hmr
# ```
# The produced outputs are:

# %%
dfOutput1 = pd.read_csv('./tutorial/outputs/hmrCore_mappingFuzzyAndClassic.tsv', sep = '\t')
dfOutput1.head()
# Out:
#                                                 Name  \
# 0                 2'-Deoxyguanosine 5'-monophosphate
# 1                                     Isocitric acid
# 2  4alpha-Carboxy-4beta-methyl-5alpha-cholesta-8,...
# 3                              (2E)-Dodecenoyl-[acp]
# 4                                       Pyruvic acid
#
#                             Identifiers_fuzzy  \
# 0                         ['C00362', '16192']
# 1                ['30887', '16087', 'C00311']
# 2  ['C15808', '64925', '50591', '|CPD-4577|']
# 3                         ['C05758', '10725']
# 4                ['C00022', '15361', '32816']
#
#                              Identifiers_classic  \
# 0                            ['C00362', '16192']
# 1  ['151', '24885', 'C00311', '30887', 'C00451']
# 2                            ['C15808', '50591']
# 3                            ['10725', 'C05758']
# 4       ['32816', 'C00022', 'PYRUVATE', '15361']
#
#                                          Identifiers
# 0                                ['C00362', '16192']
# 1  ['C00451', '16087', 'C00311', '30887', '24885'...
# 2         ['C15808', '64925', '50591', '|CPD-4577|']
# 3                                ['C05758', '10725']
# 4           ['C00022', '15361', 'PYRUVATE', '32816']

# %% [markdown]
# **Step 5. reactionsIdentification**
# To run the script from the Jupyter notebook:
# ```
# !python pipeline/reactionsIdentification.py hmr
# ```
#
# In alternative, to run the script from the terminal:
# ```
# python pipeline/reactionsIdentification.py hmr
# ```
# The produced outputs are:

# %%
dfOutput1 = pd.read_csv('./tutorial/outputs/hmrCore_metabolites_enriched.csv', sep = '\t')
dfOutput1.head()
# Out:
#               Id           Name  KeggId  ChebiId  PubchemId  \
# 0    M_biomass_s       biomasss     NaN      NaN        NaN
# 1    M_glucose_s      D-Glucose     NaN      NaN        NaN
# 2   M_lactateL_s  L-Lactic acid     NaN      NaN        NaN
# 3         M_O2_s         Oxygen     NaN      NaN        NaN
# 4  M_glutamine_s    L-Glutamine     NaN      NaN        NaN
#
#    boundaryCondition  chemicalFormula  Inchi  \
# 0              False              NaN    NaN
# 1              False              NaN    NaN
# 2              False              NaN    NaN
# 3              False              NaN    NaN
# 4              False              NaN    NaN
#
#                                         lIdentifiers
# 0                                                 []
# 1  ['42758', '|CPD-15374|', '4167', 'C00031', '17...
# 2  ['|L-LACTATE|', '16651', 'L-LACTATE', '422', '...
# 3  ['|OXYGEN-MOLECULE|', '25805', '15379', 'C00007']
# 4  ['32666', '30011', 'GLN', '|GLN|', '58359', 'C...

# %%
dfOutput2 = pd.read_csv('./tutorial/outputs/hmrCore_reactions.csv', sep = '\t')
dfOutput2.head()
# Out:
#               Rxn  KeggId EC number  GPR       Name  IsTransport  \
# 0    R_Ex_biomass     NaN        []  NaN  DmBiomass        False
# 1    R_Ex_glucose     NaN        []  NaN          *        False
# 2   R_Ex_lactateL     NaN        []  NaN          *        False
# 3         R_Ex_O2     NaN        []  NaN          *        False
# 4  R_Ex_glutamine     NaN        []  NaN          *        False
#
#   trasportedMets  IsExchange GPRrule
# 0             []        True     NaN
# 1             []        True     NaN
# 2             []        True     NaN
# 3             []        True     NaN
# 4             []        True     NaN

# %%
dfOutput3 = pd.read_csv('./tutorial/outputs/hmrCore_reactions_wIds.csv', sep = '\t')
dfOutput3.head()
# Out:
#             Rxn PutativeIdentifiers
# 0    Ex_biomass                  []
# 1    Ex_glucose                  []
# 2   Ex_lactateL                  []
# 3         Ex_O2                  []
# 4  Ex_glutamine                  []

# %%
dfOutput4 = pd.read_csv('./tutorial/outputs/hmrCore_reactions_enriched.csv', sep = '\t')
dfOutput4.head()
# Out:
#               Rxn  KeggId EC number  GPR       Name  IsTransport  \
# 0    R_Ex_biomass     NaN        []  NaN  DmBiomass        False
# 1    R_Ex_glucose     NaN        []  NaN          *        False
# 2   R_Ex_lactateL     NaN        []  NaN          *        False
# 3         R_Ex_O2     NaN        []  NaN          *        False
# 4  R_Ex_glutamine     NaN        []  NaN          *        False
#
#   trasportedMets  IsExchange GPRrule PutativeIdentifiers
# 0             []        True     NaN                  []
# 1             []        True     NaN                  []
# 2             []        True     NaN                  []
# 3             []        True     NaN                  []
# 4             []        True     NaN                  []

# %% [markdown]
# **Step 6. reactionsIdentification_TCDB**
# To run the script from the Jupyter notebook:
# ```
# !python pipeline/reactionsIdentification_TCDB.py hmr
# ```
#
# In alternative, to run the script from the terminal:
# ```
# python pipeline/reactionsIdentification_TCDB.py hmr
# ```
# The produced outputs are:

# %%
dfOutput1 = pd.read_csv('./tutorial/outputs/hmrCore_reactions_enriched_tcdb.csv', sep = '\t')
dfOutput1.head()
# Out:
#               Rxn  KeggId EC number  GPR       Name  IsTransport  \
# 0    R_Ex_biomass     NaN        []  NaN  DmBiomass        False
# 1    R_Ex_glucose     NaN        []  NaN          *        False
# 2   R_Ex_lactateL     NaN        []  NaN          *        False
# 3         R_Ex_O2     NaN        []  NaN          *        False
# 4  R_Ex_glutamine     NaN        []  NaN          *        False
#
#   trasportedMets  IsExchange GPRrule  \
# 0             []        True     NaN
# 1             []        True     NaN
# 2             []        True     NaN
# 3             []        True     NaN
# 4             []        True     NaN
#
#                                 Identifiers_fromTCDB
# 0                                                 {}
# 1  {'1.B.19.1.1': ['Q51485'], '1.B.24.1.1': ['Q9R...
# 2  {'1.A.16.2.7': ['SCP04225.1'], '1.A.8.9.14': [...
# 3  {'1.A.8.11.3': ['P61837'], '3.D.4.2.1': ['Q5SJ...
# 4  {'1.A.24.1.1': ['P08050'], '1.B.2.1.1': ['P103...

# %% [markdown]
# **Step 7. fromReactions2Genes**
# To run the script from the Jupyter notebook:
# ```
# !python pipeline/fromReactions2Genes.py hmr
# ```
#
# In alternative, to run the script from the terminal:
# ```
# python pipeline/fromReactions2Genes.py hmr
# ```
# The produced outputs are:

# %%
dfOutput1 = pd.read_csv('./tutorial/outputs/hmrCore_reactions_wGenes.csv', sep = '\t')
dfOutput1.head()
# Out:
#               Rxn  KeggId_x EC number_x  GPR_x     Name_x  IsTransport_x  \
# 0    R_Ex_biomass       NaN          []    NaN  DmBiomass          False
# 1    R_Ex_glucose       NaN          []    NaN          *          False
# 2   R_Ex_lactateL       NaN          []    NaN          *          False
# 3         R_Ex_O2       NaN          []    NaN          *          False
# 4  R_Ex_glutamine       NaN          []    NaN          *          False
#
#   trasportedMets_x  IsExchange_x GPRrule_x PutativeIdentifiers  ...  GPR_y  \
# 0               []          True       NaN                  []  ...    NaN
# 1               []          True       NaN                  []  ...    NaN
# 2               []          True       NaN                  []  ...    NaN
# 3               []          True       NaN                  []  ...    NaN
# 4               []          True       NaN                  []  ...    NaN
#
#       Name_y  IsTransport_y trasportedMets_y  IsExchange_y GPRrule_y  \
# 0  DmBiomass          False               []          True       NaN
# 1          *          False               []          True       NaN
# 2          *          False               []          True       NaN
# 3          *          False               []          True       NaN
# 4          *          False               []          True       NaN
#
#                                 Identifiers_fromTCDB      Rxn_conv  \
# 0                                                 {}    Ex_biomass
# 1  {'1.B.19.1.1': ['Q51485'], '1.B.24.1.1': ['Q9R...    Ex_glucose
# 2  {'1.A.16.2.7': ['SCP04225.1'], '1.A.8.9.14': [...   Ex_lactateL
# 3  {'1.A.8.11.3': ['P61837'], '3.D.4.2.1': ['Q5SJ...         Ex_O2
# 4  {'1.A.24.1.1': ['P08050'], '1.B.2.1.1': ['P103...  Ex_glutamine
#
#                                               lGenes lEC
# 0                                                 []  []
# 1  [['6513'], ['6514'], ['81031'], ['6517'], ['15...  []
# 2  [['366'], ['6566'], ['9121'], ['151473'], ['16...  []
# 3                                                 []  []
# 4  [['7504'], ['54868'], ['140679'], ['145389'], ...  []
#
# [5 rows x 22 columns]

# %% [markdown]
# **Step 8. genesLocationFilter**
# To run the script from the Jupyter notebook:
# ```
# !python pipeline/genesLocationFilter.py hmr
# ```
#
# In alternative, to run the script from the terminal:
# ```
# python pipeline/genesLocationFilter.py hmr
# ```
# The produced outputs are:

# %%
dfOutput1 = pd.read_csv('./tutorial/outputs/hmrCore_genes2Compartments.csv', sep = '\t')
dfOutput1.head()
# Out:
#      Gene                   lCompartments
# 0  162515               ['extracellular']
# 1    6647  ['mitochondrion', 'cytoplasm']
# 2   80007  ['mitochondrion', 'cytoplasm']
# 3  114134  ['cytoplasm', 'extracellular']
# 4   54407  ['cytoplasm', 'extracellular']

# %% [markdown]
# **Step 9. fromReactions2Genes_wFilteredData**
# To run the script from the Jupyter notebook:
# ```
# !python pipeline/fromReactions2Genes_wFilteredData.py hmr
# ```
#
# In alternative, to run the script from the terminal:
# ```
# python pipeline/fromReactions2Genes_wFilteredData.py hmr
# ```
# The produced outputs are:

# %%
dfOutput1 = pd.read_csv('./tutorial/outputs/hmrCore_genes2Compartments_wFilter.csv', sep = '\t')
dfOutput1.head()
# Out:
#               Rxn  KeggId_x EC number_x  GPR_x     Name_x  IsTransport_x  \
# 0    R_Ex_biomass       NaN          []    NaN  DmBiomass          False
# 1    R_Ex_glucose       NaN          []    NaN          *          False
# 2   R_Ex_lactateL       NaN          []    NaN          *          False
# 3         R_Ex_O2       NaN          []    NaN          *          False
# 4  R_Ex_glutamine       NaN          []    NaN          *          False
#
#   trasportedMets_x  IsExchange_x GPRrule_x PutativeIdentifiers  ...  \
# 0               []          True       NaN                  []  ...
# 1               []          True       NaN                  []  ...
# 2               []          True       NaN                  []  ...
# 3               []          True       NaN                  []  ...
# 4               []          True       NaN                  []  ...
#
#       Name_y IsTransport_y  trasportedMets_y IsExchange_y  GPRrule_y  \
# 0  DmBiomass         False                []         True        NaN
# 1          *         False                []         True        NaN
# 2          *         False                []         True        NaN
# 3          *         False                []         True        NaN
# 4          *         False                []         True        NaN
#
#                                 Identifiers_fromTCDB      Rxn_conv  \
# 0                                                 {}    Ex_biomass
# 1  {'1.B.19.1.1': ['Q51485'], '1.B.24.1.1': ['Q9R...    Ex_glucose
# 2  {'1.A.16.2.7': ['SCP04225.1'], '1.A.8.9.14': [...   Ex_lactateL
# 3  {'1.A.8.11.3': ['P61837'], '3.D.4.2.1': ['Q5SJ...         Ex_O2
# 4  {'1.A.24.1.1': ['P08050'], '1.B.2.1.1': ['P103...  Ex_glutamine
#
#                                               lGenes lEC  \
# 0                                                 []  []
# 1  [['6513'], ['6514'], ['81031'], ['6517'], ['15...  []
# 2  [['366'], ['6566'], ['9121'], ['151473'], ['16...  []
# 3                                                 []  []
# 4  [['7504'], ['54868'], ['140679'], ['145389'], ...  []
#
#                                      lGenes_filtered
# 0                                                 []
# 1  [['6513'], ['6514'], ['81031'], ['6517'], ['15...
# 2  [['366'], ['6566'], ['9121'], ['151473'], ['16...
# 3                                                 []
# 4  [['7504'], ['54868'], ['140679'], ['145389'], ...
#
# [5 rows x 23 columns]

# %% [markdown]
# **Step 10. prepareGPRulerInput**
# To run the script from the Jupyter notebook:
# ```
# !python pipeline/prepareGPRulerInput.py hmr
# ```
#
# In alternative, to run the script from the terminal:
# ```
# python pipeline/prepareGPRulerInput.py hmr
# ```
# The produced outputs are:

# %%
dfOutput1 = pd.read_csv('./tutorial/outputs/HMRcore_Rxns2Genes.csv', sep = '\t')
dfOutput1.head()
# Out:
#               Rxn                                              Genes
# 0    R_Ex_biomass                                                 []
# 1    R_Ex_glucose  [['6513'], ['6514'], ['81031'], ['6517'], ['15...
# 2   R_Ex_lactateL  [['366'], ['6566'], ['9121'], ['151473'], ['16...
# 3         R_Ex_O2                                                 []
# 4  R_Ex_glutamine  [['7504'], ['54868'], ['140679'], ['145389'], ...

# %%
dfOutput2 = pd.read_csv('./tutorial/outputs/HMRcore_Kegg2UniprotGenes.csv', sep = '\t')
dfOutput2.head()
# Out:
#    keggId uniprotId
# 0       1    P04217
# 1       1    V9HWD8
# 2      10    P11245
# 3      10    A4Z6T7
# 4     100    P00813

# %% [markdown]
# **Step 11. GPRULER**
# To run the script from the Jupyter notebook:
# ```
# !python pipeline/GPRULER.py hmr
# ```
#
# In alternative, to run the script from the terminal:
# ```
# python pipeline/GPRULER.py hmr
# ```
# The produced outputs are:

# %%
dfOutput1 = pd.read_csv('./tutorial/outputs/HMRcore_GenesData.csv', sep = '\t')
dfOutput1.head()
# Out:
#    keggId uniprotId                                       proteinNames  \
# 0   10057    O15440  ['Multidrug resistance-associated protein 5', ...
# 1   10146    Q13283  ['Ras GTPase-activating protein-binding protei...
# 2   10146    Q5U0Q1                                                 []
# 3   10146    Q6ZP53                                                 []
# 4   10165    Q9UJS0  ['Calcium-binding mitochondrial carrier protei...
#
#                                 geneNames  \
# 0                       ['ABCC5', 'MRP5']
# 1                       ['G3BP1', 'G3BP']
# 2  ['DKFZp686L1159', 'G3BP', 'hCG_39146']
# 3                                      []
# 4                 ['SLC25A13', 'ARALAR2']
#
#                                          txt_subunit  \
# 0                                                NaN
# 1  (Microbial infection) Interacts with Sindbis v...
# 2                                                NaN
# 3                                                NaN
# 4                        Homodimer (via N-terminus).
#
#                                             function  \
# 0  Acts as a multispecific organic anion pump whi...
# 1  ATP- and magnesium-dependent helicase that pla...
# 2                                                NaN
# 3                                                NaN
# 4  Mitochondrial and calcium-binding carrier that...
#
#                                           id_uniprot complexPortal  \
# 0  ['O15440', 'B9EIQ2', 'O14517', 'Q29ZA9', 'Q29Z...           NaN
# 1                               ['Q13283', 'Q5HYE9']           NaN
# 2                                         ['Q5U0Q1']           NaN
# 3                                         ['Q6ZP53']           NaN
# 4  ['Q9UJS0', 'O14566', 'O14575', 'Q546F9', 'Q9NZ...           NaN
#
#   complexPortal_uniprotId complexPortal_protName  ...  \
# 0                      []                     []  ...
# 1                      []                     []  ...
# 2                      []                     []  ...
# 3                      []                     []  ...
# 4                      []                     []  ...
#
#                                        otherSubunits subunitsFromName  \
# 0                                                 []               []
# 1  ['es', 'bind', 'viral', 'rnas', 'and', 'probab...               []
# 2                                                 []               []
# 3                                                 []               []
# 4                                                 []               []
#
#   otherIsoforms isoformIndication subunitIndication sameEnzymeMembership  \
# 0            []             False             False                False
# 1            []             False             False                False
# 2            []             False             False                False
# 3            []             False             False                False
# 4            []             False             False                False
#
#   redundancy                                     stringSubunits  \
# 0         []                                                 []
# 1         []  ['YBX1', 'EIF4G1', 'TIA1', 'CAPRIN1', 'NUFIP2'...
# 2         []                                                 []
# 3         []                                                 []
# 4         []                                                 []
#
#                     isoform                                  geneName_fromKEGG
# 0                 ['ABCC5']  ['ABCC5', ' ABC33', ' EST277145', ' MOAT-C', '...
# 1                 ['G3BP1']                    ['G3BP1', ' G3BP', ' HDH-VIII']
# 2                 ['G3BP1']                    ['G3BP1', ' G3BP', ' HDH-VIII']
# 3                 ['G3BP1']                    ['G3BP1', ' G3BP', ' HDH-VIII']
# 4  ['SLC25A12', 'SLC25A13']  ['SLC25A13', ' ARALAR2', ' CITRIN', ' CTLN2', ...
#
# [5 rows x 24 columns]

# %%
dfOutput2 = pd.read_csv('./tutorial/outputs/HMRcore_GenesRelationships.csv', sep = '\t')
dfOutput2.head()
# Out:
#                                      gene  \
# 0                       ['ABCC5', 'MRP5']
# 1                       ['G3BP1', 'G3BP']
# 2  ['DKFZp686L1159', 'G3BP', 'hCG_39146']
# 3                                      []
# 4                 ['SLC25A13', 'ARALAR2']
#
#                                            uniprotId         AND            OR
# 0  ['O15440', 'B9EIQ2', 'O14517', 'Q29ZA9', 'Q29Z...          []            []
# 1                               ['Q13283', 'Q5HYE9']  ['3', 's']            []
# 2                                         ['Q5U0Q1']          []            []
# 3                                         ['Q6ZP53']          []            []
# 4  ['Q9UJS0', 'O14566', 'O14575', 'Q546F9', 'Q9NZ...          []  ['SLC25A12']

# %%
dfOutput3 = pd.read_csv('./tutorial/outputs/HMRcore_gprRules.csv', sep = '\t')
dfOutput3.head()
# Out:
#               Rxn                                              Genes  \
# 0    R_Ex_biomass                                                 []
# 1    R_Ex_glucose  [['6513'], ['6514'], ['81031'], ['6517'], ['15...
# 2   R_Ex_lactateL  [['366'], ['6566'], ['9121'], ['151473'], ['16...
# 3         R_Ex_O2                                                 []
# 4  R_Ex_glutamine  [['7504'], ['54868'], ['140679'], ['145389'], ...
#
#                                             GPR rule
# 0                                                NaN
# 1  6514 or 50651 or 81031 or 154091 or 6515 or 29...
# 2  159963 or 9120 or 220963 or 160728 or 9390 or ...
# 3                                                NaN
# 4  (8140 and 6510) or 9057 or 120103 or 124565 or...
