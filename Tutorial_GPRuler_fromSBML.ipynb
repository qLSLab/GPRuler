# %% [markdown]
# # Tutorial: GPRuler using HMRcore model
# This tutorial explains how to use GPRuler with an SBML model as input.

# %%
import pandas as pd

# %% [markdown]
# **Step 1. metaboliteIdentification**
# To run the script from the Jupyter notebook:
# ```
# !python pipeline/metaboliteIdentification.py hmr
# ```
#
# In alternative, to run the script from the terminal:
# ```
# python pipeline/metaboliteIdentification.py hmr
# ```
#
# The two produced outputs are:

# %%
dfOutput1 = pd.read_csv('./tutorial/outputs/hmrCore_metabolites.csv', sep = '\t')
dfOutput1.head()
# Out:
#               Id           Name  KeggId  ChebiId  PubchemId  \
# 0    M_biomass_s       biomasss     NaN      NaN        NaN
# 1    M_glucose_s      D-Glucose     NaN      NaN        NaN
# 2   M_lactateL_s  L-Lactic acid     NaN      NaN        NaN
# 3         M_O2_s         Oxygen     NaN      NaN        NaN
# 4  M_glutamine_s    L-Glutamine     NaN      NaN        NaN
#
#    boundaryCondition  chemicalFormula  Inchi
# 0              False              NaN    NaN
# 1              False              NaN    NaN
# 2              False              NaN    NaN
# 3              False              NaN    NaN
# 4              False              NaN    NaN

# %%
dfOutput2 = pd.read_csv('./tutorial/outputs/hmrCore_metabolites_wInferredIds.csv', sep = '\t')
dfOutput2.head()
# Out:
#                                            Name  \
# 0                              2-Oxoglutaramate
# 1                                           GTP
# 2  (R)-3-Hydroxyoctanoyl-[acyl-carrier protein]
# 3           Flavin Adenine Dinucleotide Reduced
# 4                                    Folic acid
#
#                                          Identifiers
# 0                       ['C00940', '30882', '16769']
# 1                       ['15996', 'C00044', '37565']
# 2                                         ['C04620']
# 3                                                 []
# 4  ['67011', 'CPD-12826', '62501', 'C00504', '374...

# %% [markdown]
# **Step 2. metabolitesIdentification_FuzzyWuzzy**
# To run the script from the Jupyter notebook:
# ```
# !python pipeline/metabolitesIdentification_FuzzyWuzzy.py hmr
# ```
#
# In alternative, to run the script from the terminal:
# ```
# python pipeline/metabolitesIdentification_FuzzyWuzzy.py hmr
# ```
# The produced outputs are:

# %%
dfOutput1 = pd.read_csv('./tutorial/outputs/hmrCore_mappingMetaCyc_allResults.tsv', sep = '\t')
dfOutput1.head()
# Out:
#                            Unnamed: 0  \
# 0                      Isocitric acid
# 1                                 GMP
# 2     5Alpha-Cholesta-8,24-Dien-3-One
# 3  2'-Deoxyguanosine 5'-monophosphate
# 4                                dUDP
#
#                                                  0  \
# 0  ('(+)-dehydrodiconiferyl acid carboxylate', 86)
# 1                                     ('GMP', 100)
# 2        ('5&alpha;-cholesta-7,24-dien-3-one', 94)
# 3       ("2'-deoxyguanosine 3'-monophosphate", 97)
# 4                                    ('dUDP', 100)
#
#                                             1  \
# 0             ('juvenile hormone I acid', 86)
# 1                           ('8-oxo-GMP', 90)
# 2        ('5&alpha;-cholesta-8-en-3-one', 88)
# 3  ("2'-deoxyadenosine 3'-monophosphate", 91)
# 4                                 ('UDP', 86)
#
#                                                    2  \
# 0                  ('juvenile hormone III acid', 86)
# 1                                 ('cyclic-GMP', 90)
# 2  ('(R)-3,4-dihydroxymandelonitrile &beta;-D-glu...
# 3         ("3'-deoxyadenosine 5'-monophosphate", 91)
# 4                                       ('dUMP', 75)
#
#                                                    3  \
# 0                   ('juvenile hormone II acid', 86)
# 1                                 ('8-oxo-dGMP', 90)
# 2  ('2-amino-3-[(2,5-dihydroxyphenyl)sulfanyl]pro...
# 3                          ("2'-deoxyguanosine", 90)
# 4                                       ('dTDP', 75)
#
#                                                    4  \
# 0                    ('dihydromonacolin L acid', 86)
# 1                                ('3-deaza-GMP', 90)
# 2  ("3,5-di-C-glucosyl-2,4,4',6-tetrahydroxydiben...
# 3                                  ('phosphate', 90)
# 4                                       ('dUTP', 75)
#
#                                                    5  \
# 0  ('3&alpha;-hydroxy-3,5-dihydromonacolin L acid...
# 1                                       ('dGMP', 86)
# 2  ('2-[2-(1,3-dioxan-2-yl)ethanesulfinyl]-5-phen...
# 3                                  ('guanosine', 90)
# 4                                       ('dCDP', 75)
#
#                                                    6  \
# 0  ('O-perylenebutylmethylphosphonic-acid-p-nitro...
# 1                                        ('UMP', 67)
# 2  ('2-((2-(1,3-dioxan-2-yl)ethyl)thio)-5-phenyl-...
# 3  ('2-amino-3-[(2,5-dihydroxyphenyl)sulfanyl]pro...
# 4                                       ('dGDP', 75)
#
#                                                    7  \
# 0                  ('8-demethylnovobiocic acid', 86)
# 1                                        ('CMP', 67)
# 2  ('(2E,5S,6E,8E,10E)-1-aminododeca-2,6,8,10-tet...
# 3  ("3,5-di-C-glucosyl-2,4,4',6-tetrahydroxydiben...
# 4                                       ('dADP', 75)
#
#                                                    8  \
# 0           ('ulvanobiouronic acid 3-sulfate A', 86)
# 1                                        ('pGp', 67)
# 2  ('(3Z,5S,6E,8E,10E)-1-aminododeca-3,6,8,10-tet...
# 3  ('2-[2-(1,3-dioxan-2-yl)ethanesulfinyl]-5-phen...
# 4                                       ('dIDP', 75)
#
#                                                    9
# 0           ('ulvanobiouronic acid 3-sulfate B', 86)
# 1                                        ('GDP', 67)
# 2  ('(1E,3S,4Z)-7-amino-1-{3-[(1E)-prop-1-en-1-yl...
# 3  ('2-((2-(1,3-dioxan-2-yl)ethyl)thio)-5-phenyl-...
# 4                  ('UDP-N-acetylbacillosamine', 68)

# %%
dfOutput2 = pd.read_csv('./tutorial/outputs/hmrCore_mappingKeggC_allResults.tsv', sep = '\t')
dfOutput2.head()
# Out:
#                            Unnamed: 0  \
# 0                      Isocitric acid
# 1                                 GMP
# 2     5Alpha-Cholesta-8,24-Dien-3-One
# 3  2'-Deoxyguanosine 5'-monophosphate
# 4                                dUDP
#
#                                              0  \
# 0                      ('Isocitric acid', 100)
# 1                                 ('GMP', 100)
# 2     ('5alpha-Cholesta-8,24-dien-3-one', 100)
# 3  ("2'-Deoxyguanosine 5'-monophosphate", 100)
# 4                                ('dUDP', 100)
#
#                                             1  \
# 0              ('D-threo-Isocitric acid', 90)
# 1                  ("3',5'-Cyclic diGMP", 90)
# 2  ('5alpha-Cholesta-8,24-dien-3beta-ol', 89)
# 3        ('Deoxyguanosine monophosphate', 95)
# 4                                   ('P', 90)
#
#                                                    2  \
# 0                                       ('Acid', 90)
# 1                                     ('cdiGMP', 90)
# 2  ('6alpha,9-Difluoro-11beta-hydroxypregn-4-ene-...
# 3         ("2'-Deoxyadenosine 5'-monophosphate", 94)
# 4                                        ('UDP', 86)
#
#                                                    3  \
# 0                                         ('RI', 90)
# 1                   ("Bis-(3',5')-cyclic diGMP", 90)
# 2  ('Cyanidin 3-O-(2-O-beta-D-glucuronosyl)-beta-...
# 3             ("2'-Deoxyguanosine 5'-phosphate", 94)
# 4                                       ('dTDP', 75)
#
#                                           4  \
# 0          ('D-erythro-Isocitric acid', 90)
# 1                                 ('P', 90)
# 2               ('3-Oxo-5beta-steroid', 86)
# 3  ("2'-Deoxyguanosine 5'-diphosphate", 91)
# 4                              ('dCDP', 75)
#
#                                                    5  \
# 0                                ('Citric acid', 88)
# 1                                  ('8-Br-cGMP', 90)
# 2  ('4alpha-Carboxy-5alpha-cholesta-8,24-dien-3be...
# 3                                  ('Phosphate', 90)
# 4                                       ('CDDP', 75)
#
#                                                    6  \
# 0     ('Trimethylcolchicinic acid methyl ether', 86)
# 1                          ('8-Bromocyclic GMP', 90)
# 2  ('9-Hydroxy-3,5,7,11,13,15,17-octaoxo-nonadeca...
# 3          ("2'-Deoxyguanosine 5'-triphosphate", 90)
# 4                                       ('EDDP', 75)
#
#                                                    7  \
# 0             ('2-n-Propyl-4-oxopentanoic acid', 86)
# 1                              ('N7-Methyl-GMP', 90)
# 2  ("(9Z,11E,1'E,3'Z)-12-(1',3'-Hexadienyloxy)-9,...
# 3                                  ('Guanosine', 90)
# 4                                       ('dXDP', 75)
#
#                                8  \
# 0  ('Aromatic L-amino acid', 86)
# 1             ('8-Oxo-dGMP', 90)
# 2           ('8-Methyl-IQX', 86)
# 3         ('Deoxyguanosine', 90)
# 4                   ('EDDP', 75)
#
#                                                    9
# 0                    ('Oleic acid methyl ester', 86)
# 1                                  ('8-Oxo-GMP', 90)
# 2  ('Cyanidin 3-O-beta-D-glucoside 5-O-(6-coumaro...
# 3                          ("2'-Deoxyguanosine", 90)
# 4                                       ('dUMP', 75)

# %%
dfOutput3 = pd.read_csv('./tutorial/outputs/hmrCore_mappingKeggG_allResults.tsv', sep = '\t')
dfOutput3.head()
# Out:
#                            Unnamed: 0                              0  \
# 0                      Isocitric acid  ('UDP-D-glucuronic acid', 86)
# 1                                 GMP                    ('GM3', 67)
# 2     5Alpha-Cholesta-8,24-Dien-3-One                   ('MS 8', 86)
# 3  2'-Deoxyguanosine 5'-monophosphate           ('Sialyldi-Y-2', 86)
# 4                                dUDP                    ('UDP', 86)
#
#                                                    1  \
# 0                      ('Polygalacturonic acid', 86)
# 1                                        ('GM3', 67)
# 2  ("3-Deoxy-D-manno-octulosonyl-2',3',2',3'-tetr...
# 3                               ('Glycolipid 2', 86)
# 4                                 ('UDP-xylose', 68)
#
#                                                    2  \
# 0                ('CMP-N-acetylneuraminic acid', 86)
# 1                                        ('GM4', 67)
# 2  ('alpha-Kdo-(2->8)-[alpha-Kdo-(2->4)]-alpha-Kd...
# 3                     ("Adenosine 5'-phosphate", 86)
# 4                            ('UDP-L-arabinose', 68)
#
#                                                    3  \
# 0  ('homopolymer of alpha 2,8-N-acetyl neuraminic...
# 1                                        ('GM2', 67)
# 2                              ('3-Ketosucrose', 86)
# 3  ("3-Deoxy-D-manno-octulosonyl-2',3',2',3'-tetr...
# 4                              ('UDP-galactose', 68)
#
#                                                    4  \
# 0                    ('UDP-D-galacturonic acid', 86)
# 1                                        ('GM3', 67)
# 2  ('alpha-Kdo-(2->8)-alpha-Kdo-(2->4)-alpha-Kdo-...
# 3  ('alpha-Kdo-(2->8)-[alpha-Kdo-(2->4)]-alpha-Kd...
# 4                  ('UDP-N-acetylgalactosamine', 68)
#
#                               5                                   6  \
# 0           ('Pectic acid', 72)              ('Cytidylic acid', 64)
# 1                   ('GM3', 67)                         ('GDP', 67)
# 2           ('Balanitin 3', 86)                ('Glycolipid 3', 86)
# 3  ('NodRm-IV(Ac,C16:2,S)', 86)         ('delta DiH-2,N,6triS', 86)
# 4          ('UDP-D-xylose', 64)  ('UDP-N-acetyl-D-mannosamine', 64)
#
#                                      7                                   8  \
# 0             ('Pharbitic acid C', 64)                ('Alginic acid', 62)
# 1                          ('GM1', 67)                         ('CMP', 67)
# 2                         ('GL-3', 86)            ('GalpNAc-1-3-Galp', 86)
# 3        ('delta-DiH-(2,6,N)triS', 86)               ('VIM-2 antigen', 86)
# 4  ('UDP-alpha-D-galactofuranose', 64)  ('UDP-N-acetyl-D-glucosamine', 64)
#
#                                  9
# 0             ('Alginic acid', 62)
# 1                      ('GM1', 67)
# 2         ('Core 3-sialyl-Tn', 86)
# 3                    ('DWA-2', 86)
# 4  ('UDP-N-acetylglucosamine', 64)

# %%
dfOutput4 = pd.read_csv('./tutorial/outputs/hmrCore_mappingChebi_allResults.tsv', sep = '\t')
dfOutput4.head()
# Out:
#                            Unnamed: 0  \
# 0                      Isocitric acid
# 1                                 GMP
# 2     5Alpha-Cholesta-8,24-Dien-3-One
# 3  2'-Deoxyguanosine 5'-monophosphate
# 4                                dUDP
#
#                                              0  \
# 0                      ('Isocitric acid', 100)
# 1                                 ('GMP', 100)
# 2     ('5alpha-cholesta-8,24-dien-3-one', 100)
# 3  ("2'-Deoxyguanosine 5'-monophosphate", 100)
# 4                                ('dUDP', 100)
#
#                                                   1  \
# 0                           ('ISOCITRIC ACID', 100)
# 1                                      ('GMP', 100)
# 2  ('4-methyl-5alpha-cholesta-8,24-dien-3-one', 95)
# 3       ("2'-deoxyguanosine 5'-monophosphate", 100)
# 4                                     ('dUDP', 100)
#
#                                                    2  \
# 0                            ('isocitric acid', 100)
# 1                                       ('GMP', 100)
# 2  ('4-methyl-5alpha-cholesta-8(9),24-dien-3-one'...
# 3        ("2'-deoxyguanosine 5'-monophosphate", 100)
# 4                                      ('dUDP', 100)
#
#                                                   3  \
# 0                           ('isocitric acids', 97)
# 1                                      ('GMP', 100)
# 2  ('4-methyl-5alpha-cholesta-8,24-dien-3-one', 95)
# 3        ("2'-deoxyguanosine-3'-monophosphate", 97)
# 4                                     ('dUDP', 100)
#
#                                                    4  \
# 0                   ('(+)-threo-isocitric acid', 95)
# 1                                     ("3'-GMP", 90)
# 2  ('4-carboxy-5alpha-cholesta-8(9),24-dien-3-one...
# 3         ("2'-deoxyguanosine 3'-monophosphate", 97)
# 4                                          ('P', 90)
#
#                                                    5  \
# 0                     ('D-threo-Isocitric acid', 90)
# 1                                 ('Cyclic GMP', 90)
# 2  ('4-carboxy-5alpha-cholesta-8(9),24-dien-3-one...
# 3     ("2'-deoxyguanosine 5'-monophosphate(2-)", 97)
# 4                                         ('dU', 90)
#
#                                                    6  \
# 0                                       ('Acid', 90)
# 1                           ("3',5'-Cyclic GMP", 90)
# 2  ('4alpha-methyl-5alpha-cholesta-8,24-dien-3-on...
# 3               ('Deoxyguanosine monophosphate', 95)
# 4                                          ('D', 90)
#
#                                                    7  \
# 0                                         ('RI', 90)
# 1                           ("2',3'-Cyclic GMP", 90)
# 2  ('4alpha-methyl-5alpha-cholesta-8,24-dien-3-on...
# 3   ("8-oxo-2'-deoxyguanosine-5'-monophosphate", 95)
# 4                                          ('P', 90)
#
#                                          8  \
# 0                             ('[SO]', 90)
# 1                                ('P', 90)
# 2       ('5alpha-cholesta-8-en-3-one', 91)
# 3  ("Deoxyguanosine 5'-monophosphate", 95)
# 4                                ('U', 90)
#
#                                                    9
# 0                                         ('SO', 90)
# 1                                          ('G', 90)
# 2                 ('5alpha-cholesta-8-en-3-one', 91)
# 3  ("6-O-benzyl-2'-deoxyguanosine 5'-monophosphat...
# 4                                          ('U', 90)

# %% [markdown]
# **Step 3. metabolitesIdentification_FuzzyWuzzy_part2**
# To run the script from the Jupyter notebook:
# ```
# !python pipeline/metabolitesIdentification_FuzzyWuzzy_part2.py hmr
# ```
#
# In alternative, to run the script from the terminal:
# ```
# python pipeline/metabolitesIdentification_FuzzyWuzzy_part2.py hmr
# ```
# Some of the produced outputs are the following ones (not all the outputs are shown because structurally equal to the here reported ones):

# %%
dfOutput1 = pd.read_csv('./tutorial/outputs/hmrCore_mappingMetaCyc_100.tsv', sep = '\t')
dfOutput1.head()
# Out:
#    Unnamed: 0                     Name                      Matches
# 0           0                      GMP                      ['GMP']
# 1           1                     dUDP                     ['dUDP']
# 2           2  D-Erythrose 4-phosphate  ['D-erythrose 4-phosphate']
# 3           3                L-Proline                ['L-proline']
# 4           4              Cholesterol              ['cholesterol']

# %%
dfOutput2 = pd.read_csv('./tutorial/outputs/hmrCore_mappingKeggG_100.tsv', sep = '\t')
dfOutput2.head()
# Out:
#    Unnamed: 0                    Name                     Matches
# 0           0  Uridine 5'-diphosphate  ["Uridine 5'-diphosphate"]
# 1           1                     GDP                     ['GDP']

# %%
dfOutput3 = pd.read_csv('./tutorial/outputs/hmrCore_mappingChebi_100.tsv', sep = '\t')
dfOutput3.head()
# Out:
#    Unnamed: 0                                Name  \
# 0           0                      Isocitric acid
# 1           1                                 GMP
# 2           2     5Alpha-Cholesta-8,24-Dien-3-One
# 3           3  2'-Deoxyguanosine 5'-monophosphate
# 4           4                                dUDP
#
#                                   Matches
# 0                      ['Isocitric acid']
# 1                                 ['GMP']
# 2     ['5alpha-cholesta-8,24-dien-3-one']
# 3  ["2'-Deoxyguanosine 5'-monophosphate"]
# 4                                ['dUDP']

# %%
dfOutput4 = pd.read_csv('./tutorial/outputs/hmrCore_mappingKeggC_100.tsv', sep = '\t')
dfOutput4.head()
# Out:
#    Unnamed: 0                                Name  \
# 0           0                      Isocitric acid
# 1           1                                 GMP
# 2           2     5Alpha-Cholesta-8,24-Dien-3-One
# 3           3  2'-Deoxyguanosine 5'-monophosphate
# 4           4                                dUDP
#
#                                   Matches
# 0                      ['Isocitric acid']
# 1                                 ['GMP']
# 2     ['5alpha-Cholesta-8,24-dien-3-one']
# 3  ["2'-Deoxyguanosine 5'-monophosphate"]
# 4                                ['dUDP']

# %% [markdown]
# **Step 4. metabolitesIdentification_joiningData**
# To run the script from the Jupyter notebook:
# ```
# !python pipeline/metabolitesIdentification_joiningData.py hmr
# ```
#
# In alternative, to run the script from the terminal:
# ```
# python pipeline/metabolitesIdentification_joiningData.py hmr
# ```
# The produced outputs are:

# %%
dfOutput1 = pd.read_csv('./tutorial/outputs/hmrCore_mappingFuzzyAndClassic.tsv', sep = '\t')
dfOutput1.head()
# Out:
#                                                 Name  \
# 0                 2'-Deoxyguanosine 5'-monophosphate
# 1                                     Isocitric acid
# 2  4alpha-Carboxy-4beta-methyl-5alpha-cholesta-8,...
# 3                              (2E)-Dodecenoyl-[acp]
# 4                                       Pyruvic acid
#
#                             Identifiers_fuzzy  \
# 0                         ['C00362', '16192']
# 1                ['30887', '16087', 'C00311']
# 2  ['C15808', '64925', '50591', '|CPD-4577|']
# 3                         ['C05758', '10725']
# 4                ['C00022', '15361', '32816']
#
#                              Identifiers_classic  \
# 0                            ['C00362', '16192']
# 1  ['151', '24885', 'C00311', '30887', 'C00451']
# 2                            ['C15808', '50591']
# 3                            ['10725', 'C05758']
# 4       ['32816', 'C00022', 'PYRUVATE', '15361']
#
#                                          Identifiers
# 0                                ['C00362', '16192']
# 1  ['C00451', '16087', 'C00311', '30887', '24885'...
# 2         ['C15808', '64925', '50591', '|CPD-4577|']
# 3                                ['C05758', '10725']
# 4           ['C00022', '15361', 'PYRUVATE', '32816']

# %% [markdown]
# **Step 5. reactionsIdentification**
# To run the script from the Jupyter notebook:
# ```
# !python pipeline/reactionsIdentification.py hmr
# ```
#
# In alternative, to run the script from the terminal:
# ```
# python pipeline/reactionsIdentification.py hmr
# ```
# The produced outputs are:

# %%
dfOutput1 = pd.read_csv('./tutorial/outputs/hmrCore_metabolites_enriched.csv', sep = '\t')
dfOutput1.head()
# Out:
#               Id           Name  KeggId  ChebiId  PubchemId  \
# 0    M_biomass_s       biomasss     NaN      NaN        NaN
# 1    M_glucose_s      D-Glucose     NaN      NaN        NaN
# 2   M_lactateL_s  L-Lactic acid     NaN      NaN        NaN
# 3         M_O2_s         Oxygen     NaN      NaN        NaN
# 4  M_glutamine_s    L-Glutamine     NaN      NaN        NaN
#
#    boundaryCondition  chemicalFormula  Inchi  \
# 0              False              NaN    NaN
# 1              False              NaN    NaN
# 2              False              NaN    NaN
# 3              False              NaN    NaN
# 4              False              NaN    NaN
#
#                                         lIdentifiers
# 0                                                 []
# 1  ['42758', '|CPD-15374|', '4167', 'C00031', '17...
# 2  ['|L-LACTATE|', '16651', 'L-LACTATE', '422', '...
# 3  ['|OXYGEN-MOLECULE|', '25805', '15379', 'C00007']
# 4  ['32666', '30011', 'GLN', '|GLN|', '58359', 'C...

# %%
dfOutput2 = pd.read_csv('./tutorial/outputs/hmrCore_reactions.csv', sep = '\t')
dfOutput2.head()
# Out:
#               Rxn  KeggId EC number  GPR       Name  IsTransport  \
# 0    R_Ex_biomass     NaN        []  NaN  DmBiomass        False
# 1    R_Ex_glucose     NaN        []  NaN          *        False
# 2   R_Ex_lactateL     NaN        []  NaN          *        False
# 3         R_Ex_O2     NaN        []  NaN          *        False
# 4  R_Ex_glutamine     NaN        []  NaN          *        False
#
#   trasportedMets  IsExchange GPRrule
# 0             []        True     NaN
# 1             []        True     NaN
# 2             []        True     NaN
# 3             []        True     NaN
# 4             []        True     NaN

# %%
dfOutput3 = pd.read_csv('./tutorial/outputs/hmrCore_reactions_wIds.csv', sep = '\t')
dfOutput3.head()
# Out:
#             Rxn PutativeIdentifiers
# 0    Ex_biomass                  []
# 1    Ex_glucose                  []
# 2   Ex_lactateL                  []
# 3         Ex_O2                  []
# 4  Ex_glutamine                  []

# %%
dfOutput4 = pd.read_csv('./tutorial/outputs/hmrCore_reactions_enriched.csv', sep = '\t')
dfOutput4.head()
# Out:
#               Rxn  KeggId EC number  GPR       Name  IsTransport  \
# 0    R_Ex_biomass     NaN        []  NaN  DmBiomass        False
# 1    R_Ex_glucose     NaN        []  NaN          *        False
# 2   R_Ex_lactateL     NaN        []  NaN          *        False
# 3         R_Ex_O2     NaN        []  NaN          *        False
# 4  R_Ex_glutamine     NaN        []  NaN          *        False
#
#   trasportedMets  IsExchange GPRrule PutativeIdentifiers
# 0             []        True     NaN                  []
# 1             []        True     NaN                  []
# 2             []        True     NaN                  []
# 3             []        True     NaN                  []
# 4             []        True     NaN                  []

# %% [markdown]
# **Step 6. reactionsIdentification_TCDB**
# To run the script from the Jupyter notebook:
# ```
# !python pipeline/reactionsIdentification_TCDB.py hmr
# ```
#
# In alternative, to run the script from the terminal:
# ```
# python pipeline/reactionsIdentification_TCDB.py hmr
# ```
# The produced outputs are:

# %%
dfOutput1 = pd.read_csv('./tutorial/outputs/hmrCore_reactions_enriched_tcdb.csv', sep = '\t')
dfOutput1.head()
# Out:
#               Rxn  KeggId EC number  GPR       Name  IsTransport  \
# 0    R_Ex_biomass     NaN        []  NaN  DmBiomass        False
# 1    R_Ex_glucose     NaN        []  NaN          *        False
# 2   R_Ex_lactateL     NaN        []  NaN          *        False
# 3         R_Ex_O2     NaN        []  NaN          *        False
# 4  R_Ex_glutamine     NaN        []  NaN          *        False
#
#   trasportedMets  IsExchange GPRrule  \
# 0             []        True     NaN
# 1             []        True     NaN
# 2             []        True     NaN
# 3             []        True     NaN
# 4             []        True     NaN
#
#                                 Identifiers_fromTCDB
# 0                                                 {}
# 1  {'1.B.19.1.1': ['Q51485'], '1.B.24.1.1': ['Q9R...
# 2  {'1.A.16.2.7': ['SCP04225.1'], '1.A.8.9.14': [...
# 3  {'1.A.8.11.3': ['P61837'], '3.D.4.2.1': ['Q5SJ...
# 4  {'1.A.24.1.1': ['P08050'], '1.B.2.1.1': ['P103...

# %% [markdown]
# **Step 7. fromReactions2Genes**
# To run the script from the Jupyter notebook:
# ```
# !python pipeline/fromReactions2Genes.py hmr
# ```
#
# In alternative, to run the script from the terminal:
# ```
# python pipeline/fromReactions2Genes.py hmr
# ```
# The produced outputs are:

# %%
dfOutput1 = pd.read_csv('./tutorial/outputs/hmrCore_reactions_wGenes.csv', sep = '\t')
dfOutput1.head()
# Out:
#               Rxn  KeggId_x EC number_x  GPR_x     Name_x  IsTransport_x  \
# 0    R_Ex_biomass       NaN          []    NaN  DmBiomass          False
# 1    R_Ex_glucose       NaN          []    NaN          *          False
# 2   R_Ex_lactateL       NaN          []    NaN          *          False
# 3         R_Ex_O2       NaN          []    NaN          *          False
# 4  R_Ex_glutamine       NaN          []    NaN          *          False
#
#   trasportedMets_x  IsExchange_x GPRrule_x PutativeIdentifiers  ...  GPR_y  \
# 0               []          True       NaN                  []  ...    NaN
# 1               []          True       NaN                  []  ...    NaN
# 2               []          True       NaN                  []  ...    NaN
# 3               []          True       NaN                  []  ...    NaN
# 4               []          True       NaN                  []  ...    NaN
#
#       Name_y  IsTransport_y trasportedMets_y  IsExchange_y GPRrule_y  \
# 0  DmBiomass          False               []          True       NaN
# 1          *          False               []          True       NaN
# 2          *          False               []          True       NaN
# 3          *          False               []          True       NaN
# 4          *          False               []          True       NaN
#
#                                 Identifiers_fromTCDB      Rxn_conv  \
# 0                                                 {}    Ex_biomass
# 1  {'1.B.19.1.1': ['Q51485'], '1.B.24.1.1': ['Q9R...    Ex_glucose
# 2  {'1.A.16.2.7': ['SCP04225.1'], '1.A.8.9.14': [...   Ex_lactateL
# 3  {'1.A.8.11.3': ['P61837'], '3.D.4.2.1': ['Q5SJ...         Ex_O2
# 4  {'1.A.24.1.1': ['P08050'], '1.B.2.1.1': ['P103...  Ex_glutamine
#
#                                               lGenes lEC
# 0                                                 []  []
# 1  [['6513'], ['6514'], ['81031'], ['6517'], ['15...  []
# 2  [['366'], ['6566'], ['9121'], ['151473'], ['16...  []
# 3                                                 []  []
# 4  [['7504'], ['54868'], ['140679'], ['145389'], ...  []
#
# [5 rows x 22 columns]

# %% [markdown]
# **Step 8. genesLocationFilter**
# To run the script from the Jupyter notebook:
# ```
# !python pipeline/genesLocationFilter.py hmr
# ```
#
# In alternative, to run the script from the terminal:
# ```
# python pipeline/genesLocationFilter.py hmr
# ```
# The produced outputs are:

# %%
dfOutput1 = pd.read_csv('./tutorial/outputs/hmrCore_genes2Compartments.csv', sep = '\t')
dfOutput1.head()
# Out:
#      Gene                   lCompartments
# 0  162515               ['extracellular']
# 1    6647  ['mitochondrion', 'cytoplasm']
# 2   80007  ['mitochondrion', 'cytoplasm']
# 3  114134  ['cytoplasm', 'extracellular']
# 4   54407  ['cytoplasm', 'extracellular']

# %% [markdown]
# **Step 9. fromReactions2Genes_wFilteredData**
# To run the script from the Jupyter notebook:
# ```
# !python pipeline/fromReactions2Genes_wFilteredData.py hmr
# ```
#
# In alternative, to run the script from the terminal:
# ```
# python pipeline/fromReactions2Genes_wFilteredData.py hmr
# ```
# The produced outputs are:

# %%
dfOutput1 = pd.read_csv('./tutorial/outputs/hmrCore_genes2Compartments_wFilter.csv', sep = '\t')
dfOutput1.head()
# Out:
#               Rxn  KeggId_x EC number_x  GPR_x     Name_x  IsTransport_x  \
# 0    R_Ex_biomass       NaN          []    NaN  DmBiomass          False
# 1    R_Ex_glucose       NaN          []    NaN          *          False
# 2   R_Ex_lactateL       NaN          []    NaN          *          False
# 3         R_Ex_O2       NaN          []    NaN          *          False
# 4  R_Ex_glutamine       NaN          []    NaN          *          False
#
#   trasportedMets_x  IsExchange_x GPRrule_x PutativeIdentifiers  ...  \
# 0               []          True       NaN                  []  ...
# 1               []          True       NaN                  []  ...
# 2               []          True       NaN                  []  ...
# 3               []          True       NaN                  []  ...
# 4               []          True       NaN                  []  ...
#
#       Name_y IsTransport_y  trasportedMets_y IsExchange_y  GPRrule_y  \
# 0  DmBiomass         False                []         True        NaN
# 1          *         False                []         True        NaN
# 2          *         False                []         True        NaN
# 3          *         False                []         True        NaN
# 4          *         False                []         True        NaN
#
#                                 Identifiers_fromTCDB      Rxn_conv  \
# 0                                                 {}    Ex_biomass
# 1  {'1.B.19.1.1': ['Q51485'], '1.B.24.1.1': ['Q9R...    Ex_glucose
# 2  {'1.A.16.2.7': ['SCP04225.1'], '1.A.8.9.14': [...   Ex_lactateL
# 3  {'1.A.8.11.3': ['P61837'], '3.D.4.2.1': ['Q5SJ...         Ex_O2
# 4  {'1.A.24.1.1': ['P08050'], '1.B.2.1.1': ['P103...  Ex_glutamine
#
#                                               lGenes lEC  \
# 0                                                 []  []
# 1  [['6513'], ['6514'], ['81031'], ['6517'], ['15...  []
# 2  [['366'], ['6566'], ['9121'], ['151473'], ['16...  []
# 3                                                 []  []
# 4  [['7504'], ['54868'], ['140679'], ['145389'], ...  []
#
#                                      lGenes_filtered
# 0                                                 []
# 1  [['6513'], ['6514'], ['81031'], ['6517'], ['15...
# 2  [['366'], ['6566'], ['9121'], ['151473'], ['16...
# 3                                                 []
# 4  [['7504'], ['54868'], ['140679'], ['145389'], ...
#
# [5 rows x 23 columns]

# %% [markdown]
# **Step 10. prepareGPRulerInput**
# To run the script from the Jupyter notebook:
# ```
# !python pipeline/prepareGPRulerInput.py hmr
# ```
#
# In alternative, to run the script from the terminal:
# ```
# python pipeline/prepareGPRulerInput.py hmr
# ```
# The produced outputs are:

# %%
dfOutput1 = pd.read_csv('./tutorial/outputs/HMRcore_Rxns2Genes.csv', sep = '\t')
dfOutput1.head()
# Out:
#               Rxn                                              Genes
# 0    R_Ex_biomass                                                 []
# 1    R_Ex_glucose  [['6513'], ['6514'], ['81031'], ['6517'], ['15...
# 2   R_Ex_lactateL  [['366'], ['6566'], ['9121'], ['151473'], ['16...
# 3         R_Ex_O2                                                 []
# 4  R_Ex_glutamine  [['7504'], ['54868'], ['140679'], ['145389'], ...

# %%
dfOutput2 = pd.read_csv('./tutorial/outputs/HMRcore_Kegg2UniprotGenes.csv', sep = '\t')
dfOutput2.head()
# Out:
#    keggId uniprotId
# 0       1    P04217
# 1       1    V9HWD8
# 2      10    P11245
# 3      10    A4Z6T7
# 4     100    P00813

# %% [markdown]
# **Step 11. GPRULER**
# To run the script from the Jupyter notebook:
# ```
# !python pipeline/GPRULER.py hmr
# ```
#
# In alternative, to run the script from the terminal:
# ```
# python pipeline/GPRULER.py hmr
# ```
# The produced outputs are:
